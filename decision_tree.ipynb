# %% [markdown]
# # 1. Load packages and datasets

# %%
import numpy as np
import pandas as pd
import datetime

# %%
air_reserve = pd.read_csv('data/air_reserve.csv', parse_dates=['reserve_datetime', 'visit_datetime'])
hpg_reserve = pd.read_csv('data/hpg_reserve.csv', parse_dates=['reserve_datetime', 'visit_datetime'])
air_store_info = pd.read_csv('data/air_store_info.csv')
hpg_store_info = pd.read_csv('data/hpg_store_info.csv')
store_id_relation = pd.read_csv('data/store_id_relation.csv')
air_visit_data = pd.read_csv('data/air_visit_data.csv', parse_dates=['visit_date'])
date_info = pd.read_csv('data/date_info.csv', parse_dates=['calendar_date'])
sample_df = pd.read_csv('data/sample_submission.csv')
sample_df_new = pd.read_csv('data/to_be_predicted.csv', parse_dates=['date'])

# air_visit_data pivited and filtered for IDs that are in the submission file
air_visit_data_pivoted = air_visit_data[air_visit_data.air_store_id.isin(sample_df_new.air_store_id)].pivot(columns='visit_date', index='air_store_id', values='visitors')

# %% [markdown]
# # 2. Prepare data

# %%
air_visit_data_pivoted.head()
# Out:
# visit_date            2016-01-01  2016-01-02  2016-01-03  2016-01-04  \
# air_store_id
# air_00a91d42b08b08d9         NaN         NaN         NaN         NaN
# air_0164b9927d20bcc3         NaN         NaN         NaN         NaN
# air_0241aa3964b7f861         NaN         NaN        10.0         9.0
# air_0328696196e46f18         NaN         NaN         NaN         NaN
# air_034a3d5b40d5b1b1         NaN         NaN         NaN         NaN
#
# visit_date            2016-01-05  2016-01-06  2016-01-07  2016-01-08  \
# air_store_id
# air_00a91d42b08b08d9         NaN         NaN         NaN         NaN
# air_0164b9927d20bcc3         NaN         NaN         NaN         NaN
# air_0241aa3964b7f861        17.0        10.0         NaN         5.0
# air_0328696196e46f18         NaN         NaN         NaN         NaN
# air_034a3d5b40d5b1b1         NaN         NaN         NaN         NaN
#
# visit_date            2016-01-09  2016-01-10  ...  2017-04-13  2017-04-14  \
# air_store_id                                  ...
# air_00a91d42b08b08d9         NaN         NaN  ...        34.0        39.0
# air_0164b9927d20bcc3         NaN         NaN  ...        13.0         7.0
# air_0241aa3964b7f861         8.0        16.0  ...         NaN         4.0
# air_0328696196e46f18         NaN         NaN  ...         NaN         9.0
# air_034a3d5b40d5b1b1         NaN         NaN  ...        22.0        18.0
#
# visit_date            2017-04-15  2017-04-16  2017-04-17  2017-04-18  \
# air_store_id
# air_00a91d42b08b08d9         NaN         NaN        19.0        35.0
# air_0164b9927d20bcc3         1.0         NaN         2.0         1.0
# air_0241aa3964b7f861        15.0        10.0        12.0        19.0
# air_0328696196e46f18         4.0         3.0         3.0         NaN
# air_034a3d5b40d5b1b1        31.0        39.0        25.0        20.0
#
# visit_date            2017-04-19  2017-04-20  2017-04-21  2017-04-22
# air_store_id
# air_00a91d42b08b08d9        17.0        38.0        55.0        18.0
# air_0164b9927d20bcc3         8.0         1.0        26.0         6.0
# air_0241aa3964b7f861         8.0         NaN         3.0        13.0
# air_0328696196e46f18        24.0         NaN        19.0         8.0
# air_034a3d5b40d5b1b1        31.0        12.0        37.0        35.0
#
# [5 rows x 478 columns]

# %% [markdown]
# ## 2.1. Replace NaNs
# - Assume the leading NaNs in the time series are the period where data was not collected. Hence, these will remain as NaN
# - Assume the NaNs in between periods with data are the days where the store was closed. Hence, these will be replaced with zero

# %%
air_visit_data_pivoted_t = air_visit_data_pivoted.T.sort_index()

# %%
def replace_nan(time_series):
    first_idx = time_series.first_valid_index()
    # print(first_idx, type(first_idx))

    pre_first_idx = time_series[:(pd.to_datetime(first_idx)-datetime.timedelta(days=1))]
    post_first_idx = time_series[first_idx:]
    post_first_idx = post_first_idx.fillna(0)

    if len(pre_first_idx) == 0:
        return post_first_idx

    return pd.concat([pre_first_idx, post_first_idx])

# %%
# replace NaNs
air_visit_replaced = air_visit_data_pivoted_t.apply(lambda col: replace_nan(col), axis=0)

# %%
air_visit_replaced.head()
# Out:
# air_store_id  air_00a91d42b08b08d9  air_0164b9927d20bcc3  \
# visit_date
# 2016-01-01                     NaN                   NaN
# 2016-01-02                     NaN                   NaN
# 2016-01-03                     NaN                   NaN
# 2016-01-04                     NaN                   NaN
# 2016-01-05                     NaN                   NaN
#
# air_store_id  air_0241aa3964b7f861  air_0328696196e46f18  \
# visit_date
# 2016-01-01                     NaN                   NaN
# 2016-01-02                     NaN                   NaN
# 2016-01-03                    10.0                   NaN
# 2016-01-04                     9.0                   NaN
# 2016-01-05                    17.0                   NaN
#
# air_store_id  air_034a3d5b40d5b1b1  air_036d4f1ee7285390  \
# visit_date
# 2016-01-01                     NaN                   NaN
# 2016-01-02                     NaN                   NaN
# 2016-01-03                     NaN                   NaN
# 2016-01-04                     NaN                   NaN
# 2016-01-05                     NaN                   NaN
#
# air_store_id  air_0382c794b73b51ad  air_03963426c9312048  \
# visit_date
# 2016-01-01                     NaN                   NaN
# 2016-01-02                     NaN                   NaN
# 2016-01-03                     NaN                   NaN
# 2016-01-04                     NaN                  62.0
# 2016-01-05                     NaN                  30.0
#
# air_store_id  air_04341b588bde96cd  air_049f6d5b402a31b2  ...  \
# visit_date                                                ...
# 2016-01-01                    10.0                   NaN  ...
# 2016-01-02                     0.0                   NaN  ...
# 2016-01-03                     0.0                   NaN  ...
# 2016-01-04                    23.0                   NaN  ...
# 2016-01-05                    35.0                   NaN  ...
#
# air_store_id  air_fd6aac1043520e83  air_fdc02ec4a3d21ea4  \
# visit_date
# 2016-01-01                     NaN                   NaN
# 2016-01-02                     NaN                   NaN
# 2016-01-03                     NaN                   NaN
# 2016-01-04                    28.0                   NaN
# 2016-01-05                    36.0                   NaN
#
# air_store_id  air_fdcfef8bd859f650  air_fe22ef5a9cbef123  \
# visit_date
# 2016-01-01                     NaN                  21.0
# 2016-01-02                     NaN                  37.0
# 2016-01-03                     NaN                  14.0
# 2016-01-04                     NaN                   0.0
# 2016-01-05                     NaN                   0.0
#
# air_store_id  air_fe58c074ec1445ea  air_fea5dc9594450608  \
# visit_date
# 2016-01-01                     NaN                   NaN
# 2016-01-02                     NaN                   NaN
# 2016-01-03                     NaN                   NaN
# 2016-01-04                     NaN                   NaN
# 2016-01-05                    32.0                   NaN
#
# air_store_id  air_fee8dcf4d619598e  air_fef9ccb3ba0da2f7  \
# visit_date
# 2016-01-01                     NaN                   NaN
# 2016-01-02                     NaN                   NaN
# 2016-01-03                     NaN                   NaN
# 2016-01-04                     NaN                   NaN
# 2016-01-05                     NaN                   NaN
#
# air_store_id  air_ffcc2d5087e1b476  air_fff68b929994bfbd
# visit_date
# 2016-01-01                     NaN                   NaN
# 2016-01-02                     NaN                   NaN
# 2016-01-03                     NaN                   NaN
# 2016-01-04                     NaN                   NaN
# 2016-01-05                     NaN                   NaN
#
# [5 rows x 821 columns]

# %% [markdown]
# ## 2.2. Train test split - using the same day of the week for training, validation and prediction

# %%
air_visit_replaced_july = air_visit_replaced[air_visit_replaced.index >= pd.Timestamp(datetime.date(2016,7,1))]

# %%
air_visit_replaced_july = air_visit_replaced_july.join(date_info.set_index('calendar_date').drop(columns=['holiday_flg']), how='left')

# %%
air_visit_replaced_july.tail()
# Out:
#             air_00a91d42b08b08d9  air_0164b9927d20bcc3  air_0241aa3964b7f861  \
# visit_date
# 2017-04-18                  35.0                   1.0                  19.0
# 2017-04-19                  17.0                   8.0                   8.0
# 2017-04-20                  38.0                   1.0                   0.0
# 2017-04-21                  55.0                  26.0                   3.0
# 2017-04-22                  18.0                   6.0                  13.0
#
#             air_0328696196e46f18  air_034a3d5b40d5b1b1  air_036d4f1ee7285390  \
# visit_date
# 2017-04-18                   0.0                  20.0                  32.0
# 2017-04-19                  24.0                  31.0                  52.0
# 2017-04-20                   0.0                  12.0                  18.0
# 2017-04-21                  19.0                  37.0                  29.0
# 2017-04-22                   8.0                  35.0                  23.0
#
#             air_0382c794b73b51ad  air_03963426c9312048  air_04341b588bde96cd  \
# visit_date
# 2017-04-18                  26.0                  26.0                  34.0
# 2017-04-19                  22.0                  23.0                  35.0
# 2017-04-20                  24.0                  25.0                   8.0
# 2017-04-21                  24.0                  75.0                  47.0
# 2017-04-22                  40.0                  57.0                  45.0
#
#             air_049f6d5b402a31b2  ...  air_fdc02ec4a3d21ea4  \
# visit_date                        ...
# 2017-04-18                  14.0  ...                   3.0
# 2017-04-19                  12.0  ...                  11.0
# 2017-04-20                  16.0  ...                   3.0
# 2017-04-21                  13.0  ...                   4.0
# 2017-04-22                  29.0  ...                   9.0
#
#             air_fdcfef8bd859f650  air_fe22ef5a9cbef123  air_fe58c074ec1445ea  \
# visit_date
# 2017-04-18                   2.0                  20.0                   0.0
# 2017-04-19                   3.0                  20.0                   0.0
# 2017-04-20                   8.0                  11.0                   0.0
# 2017-04-21                   4.0                  26.0                   0.0
# 2017-04-22                   4.0                  22.0                  49.0
#
#             air_fea5dc9594450608  air_fee8dcf4d619598e  air_fef9ccb3ba0da2f7  \
# visit_date
# 2017-04-18                  16.0                  22.0                   0.0
# 2017-04-19                  17.0                  32.0                  13.0
# 2017-04-20                  23.0                  26.0                   1.0
# 2017-04-21                  28.0                  27.0                   3.0
# 2017-04-22                  14.0                  53.0                   5.0
#
#             air_ffcc2d5087e1b476  air_fff68b929994bfbd  day_of_week
# visit_date
# 2017-04-18                  28.0                   6.0      Tuesday
# 2017-04-19                  28.0                   2.0    Wednesday
# 2017-04-20                  23.0                   2.0     Thursday
# 2017-04-21                  54.0                   4.0       Friday
# 2017-04-22                   1.0                   5.0     Saturday
#
# [5 rows x 822 columns]

# %%
air_visit_replaced_july_sunday = air_visit_replaced_july[air_visit_replaced_july.day_of_week == 'Sunday'].drop(columns=['day_of_week']).T.dropna()

# %%
air_visit_replaced_july_sunday.head()
# Out:
# visit_date            2016-07-03  2016-07-10  2016-07-17  2016-07-24  \
# air_00a91d42b08b08d9         0.0         0.0         0.0         0.0
# air_0241aa3964b7f861        20.0         3.0        14.0        19.0
# air_0328696196e46f18        11.0         4.0         3.0        19.0
# air_034a3d5b40d5b1b1         5.0        13.0        15.0        10.0
# air_036d4f1ee7285390        37.0        52.0        10.0        21.0
#
# visit_date            2016-07-31  2016-08-07  2016-08-14  2016-08-21  \
# air_00a91d42b08b08d9         0.0         0.0         0.0         0.0
# air_0241aa3964b7f861         3.0         1.0         0.0        18.0
# air_0328696196e46f18         7.0         0.0         0.0         0.0
# air_034a3d5b40d5b1b1        16.0         5.0        26.0         6.0
# air_036d4f1ee7285390        23.0        23.0         0.0        31.0
#
# visit_date            2016-08-28  2016-09-04  ...  2017-02-12  2017-02-19  \
# air_00a91d42b08b08d9         0.0         0.0  ...         0.0         0.0
# air_0241aa3964b7f861         9.0        12.0  ...         6.0         8.0
# air_0328696196e46f18         8.0         0.0  ...        41.0         5.0
# air_034a3d5b40d5b1b1         2.0        17.0  ...        22.0        64.0
# air_036d4f1ee7285390       188.0        25.0  ...         8.0        18.0
#
# visit_date            2017-02-26  2017-03-05  2017-03-12  2017-03-19  \
# air_00a91d42b08b08d9         0.0         0.0         0.0         0.0
# air_0241aa3964b7f861         9.0         5.0         3.0        12.0
# air_0328696196e46f18         0.0        17.0         0.0        29.0
# air_034a3d5b40d5b1b1        57.0        33.0        41.0        42.0
# air_036d4f1ee7285390        23.0         7.0        23.0        25.0
#
# visit_date            2017-03-26  2017-04-02  2017-04-09  2017-04-16
# air_00a91d42b08b08d9         0.0         0.0         0.0         0.0
# air_0241aa3964b7f861         6.0        13.0        10.0        10.0
# air_0328696196e46f18         0.0         0.0         0.0         3.0
# air_034a3d5b40d5b1b1        25.0        30.0        37.0        39.0
# air_036d4f1ee7285390        15.0        28.0        15.0        30.0
#
# [5 rows x 42 columns]

# %%
# decide train, val, test size
if not air_visit_replaced_july_sunday.shape[1] % 3 == 2:
    print('adjusting shape')
    air_visit_replaced_july_sunday = air_visit_replaced_july_sunday.iloc[:, (air_visit_replaced_july_sunday.shape[1]%3)+1:]
print(air_visit_replaced_july_sunday.shape)
size = int(np.ceil(air_visit_replaced_july_sunday.shape[1]/3))
print(size)
# Out:
# adjusting shape
# (780, 41)
# 14

# %%
train_x = air_visit_replaced_july_sunday.iloc[:, :size-1]
train_y = air_visit_replaced_july_sunday.iloc[:, size-1:size]
val_x = air_visit_replaced_july_sunday.iloc[:, size:size*2-1]
val_y = air_visit_replaced_july_sunday.iloc[:, size*2-1:size*2]
test_x = air_visit_replaced_july_sunday.iloc[:, size*2:]

# %%
train_x.shape, val_x.shape, test_x.shape
# Out:
# ((780, 13), (780, 13), (780, 13))

# %%
train_x.columns[0], train_x.columns[-1], train_y.columns[0], val_x.columns[0], val_x.columns[-1], val_y.columns[0], test_x.columns[0], test_x.columns[-1]#, test_y.columns[0],
# Out:
# (Timestamp('2016-07-10 00:00:00'),
#  Timestamp('2016-10-02 00:00:00'),
#  Timestamp('2016-10-09 00:00:00'),
#  Timestamp('2016-10-16 00:00:00'),
#  Timestamp('2017-01-08 00:00:00'),
#  Timestamp('2017-01-15 00:00:00'),
#  Timestamp('2017-01-22 00:00:00'),
#  Timestamp('2017-04-16 00:00:00'))

# %% [markdown]
# # 3. Model building

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
model_tree = DecisionTreeRegressor()

# %%
model_tree.fit(train_x, train_y)
# Out:
# DecisionTreeRegressor()

# %%
pred_tree = model_tree.predict(val_x)

# %%
pred_tree
# Out:
# array([  0.  ,  16.  ,   4.  ,  10.  ,  12.  ,  42.  ,   0.  ,  38.  ,
#          5.  ,   5.  ,   5.  ,  26.  ,  49.  ,  24.  ,   5.  ,  11.  ,
#         13.  ,  22.  ,  27.  ,   0.  ,   0.  ,  22.  ,  16.  ,  20.  ,
#         20.  ,   6.  ,   4.  ,  18.  ,  10.  ,   4.  ,   3.  ,  12.  ,
#         17.  ,   0.  ,   0.24,  48.  ,  29.  ,  16.  ,  20.  ,  11.  ,
#          0.  ,   0.24,  14.  ,  14.  ,   0.24,  18.  ,  30.  ,  11.  ,
#          0.24,   4.  ,  40.  ,  20.  ,   0.24,   6.  ,  10.  ,   2.  ,
#         18.  ,  42.  ,  35.  ,  11.  ,  43.  ,   0.  ,   8.  ,  17.  ,
#         24.  ,  24.  ,   0.  ,  16.  ,  69.  ,  22.  ,   2.  ,   3.  ,
#          3.  ,   6.  ,  32.  ,   7.  ,   0.24,   8.  ,  54.  ,   9.  ,
#         13.  ,   0.  ,  46.  ,  22.  ,   0.  ,   0.  ,   5.  ,  11.  ,
#         65.  ,  24.  ,   5.  ,   8.  ,  71.  ,  17.  ,  35.  ,   2.  ,
#         72.  ,  58.  ,   4.  ,   0.  ,  30.  ,  22.  ,  33.  ,   0.  ,
#         58.  ,  26.  ,  34.  ,   0.24,  42.  ,   5.  ,   6.  ,  14.  ,
#          0.24,  20.  ,   0.24,  14.  ,  24.  ,  33.  ,   6.  ,  39.  ,
#          0.  ,   0.  ,  26.  ,   0.24,   0.  ,   0.24,  14.  ,  46.  ,
#         22.  ,   0.  ,  32.  ,   0.  ,  16.  ,   4.  ,  32.  ,  43.  ,
#          8.  ,  34.  ,  22.  ,   0.  ,  44.  ,   7.  ,  23.  ,  22.  ,
#         40.  ,   6.  ,  35.  ,   4.  ,  35.  ,  41.  ,  36.  ,  14.  ,
#          4.  ,  11.  ,  16.  ,  32.  ,  10.  ,   0.24,   4.  ,  36.  ,
#          9.  ,  50.  ,  30.  ,  22.  ,   0.  ,   0.24,   0.  ,  39.  ,
#         16.  ,  50.  ,  36.  ,   7.  ,   0.  ,   0.  ,  60.  ,   6.  ,
#         22.  ,  28.  ,  65.  ,   0.  ,   0.  ,  35.  ,   0.  ,   0.24,
#         15.  ,  32.  ,  65.  ,  42.  ,  11.  ,  26.  ,   0.24,  20.  ,
#          0.24,  39.  ,   5.  ,  68.  ,   2.  ,  22.  ,  18.  ,  13.  ,
#          0.24,  17.  ,  41.  ,   0.24,  22.  ,  16.  ,  20.  ,   6.  ,
#          0.  ,   0.  ,   0.24,  45.  ,   0.24,  46.  ,  15.  ,   3.  ,
#         22.  ,  15.  ,  16.  ,  20.  ,   0.24,  35.  ,  13.  ,  35.  ,
#          0.  ,   0.  ,  41.  ,  58.  ,   0.24,   0.24,  35.  ,  11.  ,
#          8.  ,   8.  ,  44.  ,   6.  ,   0.  ,   5.  ,   0.  ,   0.24,
#          0.24,   4.  ,  36.  ,  18.  ,  13.  ,  36.  ,   9.  ,   5.  ,
#          5.  ,  24.  ,  42.  ,  12.  ,   5.  ,  43.  ,  62.  ,  16.  ,
#         12.  ,  20.  , 169.  ,  79.  ,  22.  ,  22.  ,  14.  ,  16.  ,
#          0.  ,  20.  ,   8.  ,   0.24,  22.  ,   0.24,  30.  ,   4.  ,
#         32.  ,  34.  ,  68.  ,   0.  ,  42.  ,   9.  ,  79.  ,   5.  ,
#         43.  ,   0.  ,  25.  ,   0.  ,  14.  ,  38.  ,  22.  ,  22.  ,
#         18.  ,  16.  ,  46.  ,  16.  ,  21.  ,   4.  ,  22.  ,  10.  ,
#          0.24,  55.  ,   0.  ,  21.  ,   0.  ,  26.  ,   0.24,  79.  ,
#         10.  ,   0.  , 107.  ,  42.  ,  26.  ,  35.  ,  16.  ,  30.  ,
#          0.24,  24.  ,  52.  ,   0.24,  60.  ,  26.  ,   1.  ,   0.  ,
#          0.  ,   0.  ,  14.  ,   0.  ,  14.  ,  11.  ,   0.  ,  14.  ,
#         22.  ,   0.24,  22.  ,   3.  ,   4.  ,   0.24,  58.  ,  38.  ,
#          0.  ,   0.  ,  40.  ,   6.  ,  26.  ,  12.  ,   2.  ,  32.  ,
#          0.  ,  55.  ,   0.24,   0.  ,  53.  ,  27.  ,   0.  ,  22.  ,
#         61.  ,  10.  ,   0.24,  14.  ,  30.  ,  13.  ,  11.  ,  47.  ,
#          7.  ,  35.  ,   8.  ,   0.  ,  39.  ,   0.  ,  30.  ,  20.  ,
#          5.  ,   0.24,   8.  ,  42.  ,  12.  ,  18.  ,  36.  ,  28.  ,
#          8.  ,  35.  ,   2.  ,   2.  ,   0.  ,  33.  ,  12.  ,  22.  ,
#          0.24,   0.24,  22.  ,   5.  ,  10.  ,  22.  ,  14.  ,  31.  ,
#         35.  ,  17.  ,   0.  ,  35.  ,   0.  ,   1.  ,   5.  ,   0.  ,
#          0.24,  10.  ,   0.  ,  12.  ,  17.  ,   0.24,   0.24,  15.  ,
#          8.  ,  35.  ,   0.  ,   0.24,   0.  ,  27.  ,   0.  ,  31.  ,
#         46.  ,  14.  ,  17.  ,   8.  ,  15.  ,   2.  ,  52.  ,   0.  ,
#         22.  ,  21.  ,   4.  ,   0.  ,   4.  ,  47.  ,   6.  ,  26.  ,
#          0.24,  10.  ,   0.  ,  16.  ,  28.  ,   4.  ,   0.  ,  10.  ,
#         36.  ,  20.  ,   6.  ,  30.  ,   0.  ,  12.  ,  31.  ,   0.24,
#          0.24,   0.  ,  22.  ,  27.  ,   0.  ,  16.  ,  10.  ,   0.24,
#          0.  ,  38.  ,  22.  ,  32.  ,  52.  ,  17.  ,  18.  ,   0.24,
#         31.  ,  45.  ,  52.  ,   0.  ,  22.  ,   2.  ,   0.24,  42.  ,
#         15.  ,   6.  ,  79.  ,   0.24,  71.  ,  45.  ,   2.  ,  16.  ,
#         22.  ,  14.  ,   0.  ,   0.  ,   0.24,  16.  ,   0.  ,   4.  ,
#          0.  ,   6.  ,  26.  ,  31.  ,   0.  ,  30.  ,  14.  ,   0.  ,
#         21.  ,  23.  ,  39.  ,  36.  ,   6.  ,   0.  ,  39.  ,   6.  ,
#          0.  ,  13.  ,   0.  ,  11.  ,   8.  ,  34.  ,  15.  ,  16.  ,
#         25.  ,  10.  ,   0.  ,  38.  ,   0.  ,   0.  ,   7.  ,  12.  ,
#         17.  ,  12.  ,   8.  ,  55.  ,  22.  ,  16.  ,  10.  ,  48.  ,
#          2.  ,   2.  ,   0.  ,  31.  ,  21.  ,  14.  ,  22.  ,  12.  ,
#         69.  ,  43.  ,  30.  ,   0.  , 109.  ,   0.  ,  20.  ,  36.  ,
#         43.  ,  12.  ,  10.  ,   6.  ,  10.  ,  46.  ,  16.  ,  55.  ,
#          6.  ,   5.  ,   6.  ,  35.  ,  65.  ,   0.  ,  22.  ,   1.  ,
#         71.  ,  34.  ,   0.24,   6.  ,   0.  ,  35.  ,   0.  ,  52.  ,
#          0.  ,   0.  ,  20.  ,  45.  ,  35.  ,   5.  ,  17.  ,  39.  ,
#         23.  ,   0.24,  60.  ,  42.  ,  10.  ,   0.  ,   9.  ,  10.  ,
#          0.  ,  22.  ,  30.  ,   5.  ,  35.  ,  15.  ,   0.  ,   6.  ,
#         43.  ,  11.  ,   0.  ,   1.  ,   6.  ,  12.  ,  39.  ,  24.  ,
#          1.  ,   0.24,  19.  ,  22.  ,  17.  ,   0.  ,   0.  ,   0.  ,
#          5.  ,   0.24,   9.  ,  24.  ,   0.24,  62.  ,  30.  ,  50.  ,
#         21.  ,   2.  ,   5.  ,  25.  ,   0.  ,  24.  ,  16.  ,  10.  ,
#          0.  ,  16.  ,   1.  ,  58.  ,  34.  ,   0.24,  60.  ,   0.24,
#          6.  ,  35.  ,   4.  ,   3.  ,   0.  ,  22.  ,  16.  ,  31.  ,
#         22.  ,   5.  ,  14.  ,  11.  ,  20.  ,   0.24,   0.  ,   2.  ,
#          1.  ,   0.  ,  40.  ,  14.  ,   2.  ,   0.  ,   2.  ,   0.24,
#          0.  ,   0.24,  17.  ,  38.  ,  69.  ,   5.  ,  12.  ,   4.  ,
#         22.  ,  17.  ,  15.  ,   6.  ,  16.  ,  23.  ,  14.  ,  24.  ,
#          4.  ,  35.  ,  50.  ,  13.  ,   0.  ,  25.  ,  30.  ,   5.  ,
#         27.  ,   0.24,   0.  ,  68.  ,  45.  ,  10.  ,   0.  ,   8.  ,
#         13.  ,  35.  ,  21.  ,   0.  ,  38.  ,   0.24,   0.  ,   0.24,
#         82.  ,  82.  ,   0.  ,   0.  ,  19.  ,  35.  ,   1.  ,   5.  ,
#          5.  ,  53.  ,   0.  ,   0.24,  34.  ,  56.  ,  18.  ,   4.  ,
#         35.  ,   0.  ,  22.  ,   4.  ,  45.  ,   5.  ,  34.  ,   5.  ,
#         27.  ,   8.  ,  18.  ,   0.  ,   4.  ,   0.  ,  60.  ,  50.  ,
#         13.  ,   0.  ,   6.  ,   0.  ,  42.  ,  62.  ,   8.  ,   6.  ,
#         10.  ,   0.  ,  26.  ,  42.  ,   0.24,  22.  ,  35.  ,  29.  ,
#          0.  ,  10.  ,  11.  ,  10.  ,  35.  ,   3.  ,  11.  ,  32.  ,
#         32.  ,  15.  ,   0.  ,  15.  ,  65.  ,   0.  ,   0.24,   6.  ,
#          0.  ,  25.  ,   4.  ,   2.  ,   0.  ,  32.  ,  26.  ,  24.  ,
#          0.  ,   0.  ,   0.  ,  35.  ,   8.  ,  69.  ,   0.  ,  17.  ,
#         22.  ,  15.  ,   0.  ,   1.  ])

# %%
from sklearn.metrics import mean_squared_log_error

# %%
mean_squared_log_error(val_y, pred_tree)
# Out:
# 1.3716841998316445

# %% [markdown]
# *Issues*:
# - In the data cleaning process, IDs with NaN were dropped. This way, I cannot predict the values for all IDs present in sample submission file
# - By dropping all dates before 1 Jul 2016, it limits the amount of data that can be used for training/validation/prediction
